# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path='/content/drive/My Drive/winequality-white.csv'
file_path2='/content/drive/My Drive/winequality-red.csv'

# %%
import pandas as pd
df1=pd.read_csv(file_path)
df2=pd.read_csv(file_path2)

df1
df2

df1.head()
df2.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1   7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2  7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3  11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5

# %%
final=pd.concat([df1,df2])
print(final.head())
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 1598
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                   --------------  -----
#  0   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"  6497 non-null   object
# dtypes: object(1)
# memory usage: 101.5+ KB

# %%
final.describe()
# Out:
#        fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# count                                                6497
# unique                                               5318
# top     7.3;0.19;0.27;13.9;0.057;45;155;0.99807;2.94;0...
# freq                                                    8

# %%
final.isnull()
# Out:
#       fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 1594                                              False
# 1595                                              False
# 1596                                              False
# 1597                                              False
# 1598                                              False
#
# [6497 rows x 1 columns]

# %%
final.isnull().any()
# Out:
# fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"    False
# dtype: bool

# %%
final.isnull().sum()
# Out:
# fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"    0
# dtype: int64

# %%
final.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 6497, dtype: bool

# %%
final.drop_duplicates(inplace=True)

# %%
final
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 6     6.2;0.32;0.16;7;0.045;30;136;0.9949;3.18;0.47;...
# ...                                                 ...
# 1593  6.8;0.62;0.08;1.9;0.068;28;38;0.99651;3.42;0.8...
# 1594  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5
# 1595  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...
# 1597  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...
# 1598  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...
#
# [5318 rows x 1 columns]

# %%
final.dropna(inplace=True)

# %%
final=final.rename(columns={'fixed acidity':'acidity'})
final.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 6  6.2;0.32;0.16;7;0.045;30;136;0.9949;3.18;0.47;...

# %%
final.to_csv('/content/drive/My Drive/finalp2.csv', index=False)

# %%
print(final.columns)
# Out:
# Index(['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'], dtype='object')

# %%
finalpath='/content/drive/My Drive/finalp2.csv'
final=pd.read_csv(finalpath,delimiter=';')

print(final.head())
# Out:
#                                                            fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 7.0 0.27 0.36 20.7 0.045 45.0 170.0 1.0010 3.00 0.45 8.8                                                   6
# 6.3 0.30 0.34 1.6  0.049 14.0 132.0 0.9940 3.30 0.49 9.5                                                   6
# 8.1 0.28 0.40 6.9  0.050 30.0 97.0  0.9951 3.26 0.44 10.1                                                  6
# 7.2 0.23 0.32 8.5  0.058 47.0 186.0 0.9956 3.19 0.40 9.9                                                   6
# 6.2 0.32 0.16 7.0  0.045 30.0 136.0 0.9949 3.18 0.47 9.6                                                   6
